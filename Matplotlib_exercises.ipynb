# %% [markdown]
# # Matplotlib exercises
# Zadaniem ćwiczeń jest otrzymanie tych samych outputów które są w celach poniżej. Zadania będą zaczynały się od łatwiejszych i przechodzić będą do trudniejszych.
#
# *Uwaga: Wszystkie polecenia i komendy do danego zadania powinny być napisane w jednej i tej samej komórce, rozdzielanie ich na kilka innych komórek może spowodować, że wykres się nie narysuje.*

# %% [markdown]
# __Zaimportuj numpy oraz matplotlib jako plt oraz ustaw `%matplotlib inline` po to żeby wykresy wyświetlały się w notebooku__

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# __Ćwiczenie 1__

# %% [markdown]
# Narysuj wykres który jest w celi poniżej. Pamiętaj o ustawieniu nazwy osi x, y oraz tytułu oraz dobraniu odpowiednych danych.

# %%
x = np.linspace(0, 50, 100)
y=3*x
plt.plot(x, y, color='b')
plt.title('Draw a line')
plt.xlabel('x- axis')
plt.ylabel('y- axis')
# Out:
# Text(0, 0.5, 'y- axis')

# %% [markdown]
# __Ćwiczenie 2__

# %% [markdown]
# Narysuj wykres który jest w celi poniżej. Zdefiniuj dobrze wszystkie 3 funkcje które będą rysowane (pierwsza funkcja to funkcja liniowa, druga - kwadratowa, trzecia - x**3)

# %%
x = np.linspace(0,2,50)
plt.plot(x, x, color='b')
plt.plot(x, x**3, color='green')
plt.plot(x, x**2, color='orange')
plt.title('Draw a line')
plt.xlabel('x label')
plt.ylabel('y label')
plt.legend(['linear','quadratic','cubic'])

# %% [markdown]
# __Ćwiczenie 3__

# %% [markdown]
# Narysuj wykres który jest w celi poniżej. Zdefiniuj dobrze wszystkie 3 funkcje które będą rysowane (pierwsza funkcja to funkcja liniowa, druga - kwadratowa, trzecia - x**3). Jest to podobny wykres do poprzedniego, lecz ze zmienionym rodzajem lini.

# %%
x = np.arange(0,5,0.2)
plt.plot(x, x, 'r--') # można w jednej linijce ogarnać
plt.plot(x, x**3, 'g^')
plt.plot(x, x**2, 'bs')
plt.title('Draw a line')
plt.xlabel('x label')
plt.ylabel('y label')
# Out:
# Text(0, 0.5, 'y label')

# %% [markdown]
# __Ćwiczenie 4__

# %% [markdown]
# Narysuj wykres który jest w celi poniżej. Zdefiniuj dobrze wartości x oraz y, zmień `linestyle`, `linewidth`, `marker`, `markerfacecolor` oraz `markersize`. Ustaw również granice x oraz y a także zmień nazwy osi i tytuł wykresu.

# %%
x = [1,4,5,6,7]
y = [2,6,3,6,4]
plt.plot(x,y,linestyle ="-.", linewidth = 3, marker = 'o', markerfacecolor = 'blue', color='red', markersize = '15')
plt.xlim(1,8) # ustawiamy zakres x
plt.ylim(1,8) #ustawiamy zakres y
# Out:
# (1.0, 8.0)

# %% [markdown]
# __Ćwiczenie 5__

# %% [markdown]
# Stwórz obiekt typu `figure` a następnie za pomoć aunkcji `subplot` utwórz poniższe gridy. Dodatkowo usuń `ticky` z każdego wykresu z osi x oraz y.

# %%
fig = plt.figure()

plt.subplot(2,1,1)
x = np.linspace(0,2,50)
plt.plot(x)
plt.xticks(())
plt.yticks(())
plt.subplot(2,3,4)
plt.xticks(())
plt.yticks(())
x = np.linspace(0,2,50)
plt.plot(x)
plt.subplot(2,3,5)
x = np.linspace(0,2,50)
plt.xticks(())
plt.yticks(())
plt.plot(x)
plt.subplot(2,3,6)
x = np.linspace(0,2,50)
plt.plot(x)
plt.xticks(())
plt.yticks(())
fig.subplots_adjust(bottom = 0.2,left=0.2, right = 0.4, top = 0.4)

# %% [markdown]
# __Ćwiczenie 6__
#
# Narysuj wykres który jest w celi poniżej. Stwórz wykres słupkowy, który będzie przedstawiał 5 najbardziej popularnych języków programowania 2 2022 roku. W celu otrzymania wartości do popularności języków odwiedź stronę [Tiobe index](https://www.tiobe.com/tiobe-index/). Ustaw odpowiednie kolory wykresów. Hint: Użyj `xticks` do zmiany nazw punktów na osi X.

# %%
x = ['Python', 'C', 'Java', 'C++', 'C#']
popularity = [13.92, 12.71, 10.82, 8.28, 6.82]
xpos =  [i for i in range(len(x))] # można tak ale można po prostu wpisać x i zadziała
plt.bar(x, popularity, color = ["r", "black", 'g', 'b', 'yellow'])
plt.xlabel('Languages')
plt.ylabel('Popularity')
plt.title('Popularity...')
#plt.xticks(xpos, x)
# Out:
# Text(0.5, 1.0, 'Popularity...')

# %% [markdown]
# __Ćwiczenie 7__
#
# Przedstaw ten sam wykres co powyżej tylko dodatkowo dodaj siatkę. Hint: Możesz ją dodać używając `minorticks_on` a następnie używając `plt.grid` dodaj odpowiednio większą siatkę i mniejszą.

# %% [markdown]
# __Dane do poniższych wykresów__

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# __Ćwiczenie 8__
#
# Stwórz obiekt `figure` a następnie dodaj oś do kanwy w `[0, 0, 1, 1]` używając add_axes i ustaw odpowiednio nazwy osi oraz tytuł wykresu.

# %% [markdown]
# __Ćwiczenie 9__
#
# Narysuj wykres który jest w celi poniżej. Stwórz na początku obiekt typu `figure` a następnie dodaj do niego nowy zestaw osi: `[0,0,1,1]` i `0.2,0.5,.2,.2`. Zmień nazwy osi i tytuł.

# %% [markdown]
# __Ćwiczenie 9__
#
# Narysuj wykres który jest w celi poniżej. Stwórz dwa subploty używając funkcji `subplot` podaj `nrows` i `ncols`. Sprawdź co zwraca `plt.subplots` a następnie narysuj 2 osobne wykresy.

# %% [markdown]
# __Ćwiczenie 10__
#
# Narysuj wykres który jest w celi poniżej. Stwórz obiekt typu `figure` dodaj nowy zestaw osi `[0,0,1,1]` i `[0.2, 0.5, .4, .4]`. Następnie użyj wcześniej zdefiniowanych x oraz y do stowrzenia wykresu. Zauważ xlimity oraz ylimity w wykresie który jest wewnątrz.

# %%
print ('test')
# Out:
# test
